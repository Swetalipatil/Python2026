# %%
# . Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.

# 	Given List:

list1 = ["M", "na", "i", "Ra"]
list2 = ["y", "me", "s", "hul"]

# 	Output:

# 	[['M','y'], ['na', me'], ['i', 's'], ['Ra', 'hul']]


result = [[a, b] for a, b in zip(list1, list2)]


result.extend(list1[len(result):] or list2[len(result):])

print(result)
# Out:
# [['M', 'y'], ['na', 'me'], ['i', 's'], ['Ra', 'hul']]

# %%
#  2. Write a program to add item 7000 after 6000 in the following Python List

# 	list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
# 	Output:

# 	[10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]


list1[2][2].append(7000)

print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
# 3. Suppose you are given a list of candy and another list of same size representing no of items of respective candy.

# 	i.e -

# 	candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# 	no_of_items = [10,20,34,74,32]
# 	Write a program to show no. of items of each candy type.

# 	Output:

# 	Jelly Belly-10
# 	Kit Kat-20
# 	Double Bubble-34
# 	Milky Way-74
# 	Three Musketeers-32

candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

for candy, count in zip(candy_list, no_of_items):
    print(f"{candy}-{count}")
# Out:
# Jelly Belly-10
# Kit Kat-20
# Double Bubble-34
# Milky Way-74
# Three Musketeers-32

# %%
# 4. Running Sum on list Write a program to print a list after performing running sum on it.

# 	i.e:

# 	Input:

# 	list1 = [1,2,3,4,5,6]
# 	Output:

# 	[1,3,6,10,15,21]

list1 = [1, 2, 3, 4, 5, 6]

for i in range(1, len(list1)):
    list1[i] += list1[i - 1]

print(list1)
# Out:
# [1, 3, 6, 10, 15, 21]

# %%
# . You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.

# 	i.e. Say given list is [2,4,6,10,1] resultant list will be [22,20,10,23].

# 	For 1st element 2 ->> these are greater (4+6+10) values and 2 itself so on adding becomes 22.

# 	For 2nd element 4 ->> greater elements are (6, 10) and 4 itself, so on adding 20

# 	like wise for all other elememts.

# 	[2,4,6,10,1]-->[22,20,16,10,23]

list1 = [2, 4, 6, 10, 1]
result = []
for num in list1:
    total = 0
    for x in list1:
        if x >= num:
            total += x
    result.append(total)
print(result)
# Out:
# [22, 20, 16, 10, 23]

# %%
# 6. Find list of common unique items from two list. and show in increasing order

# 	Input

# 	num1 = [23,45,67,78,89,34]
# 	num2 = [34,89,55,56,39,67]
# 	Output:

# 	[34, 67, 89]


num1 = [23, 45, 67, 78, 89, 34]
num2 = [34, 89, 55, 56, 39, 67]
common_items = list(set(num1) & set(num2))
common_items.sort()
print(common_items)
# Out:
# [34, 67, 89]

# %%
# 7. Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.

# 	Input:

# 	['1ac21', '23fg', '456', '098d','1','kls']
# 	Output:

# 	['456', '23fg', '1ac21', '1', 'kls', '098d']

# Input list
# Out:
# ['456', '23fg', '1ac21', '1', 'kls', '098d']

# %%
import math

l = ['1ac21', '23fg', '456', '098d','1','kls']
prod_list = []
for i in l:
    digits = []
    for j in i:
        if j.isdigit():
            digits.append(int(j))
    if digits:
        prod_list.append(math.prod(digits))
    else:
        prod_list.append(1)
a = zip(prod_list, l)
b = sorted(a, reverse=True)

result = [j for i, j in b]
print(result)
# Out:
# ['456', '23fg', '1ac21', 'kls', '1', '098d']

# %%
# 8. Write a program that can find the max number of each row of a matrix
# 	Example:

# 	Input:

# 	[[1,2,3],[4,5,6],[7,8,9]]
# 	Output:

# 	[3,6,9]

matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
max_per_row = [max(row) for row in matrix]
print(max_per_row)
# Out:
# [3, 6, 9]

# %%
# 9. Shortlist Students for a Job role Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.

# 	Show every students record in form of tuples if matches all required criteria.

# 	It is assumed that there will be only one primry skill.

# 	If no such candidate found, print No such candidate

# 	Input:

# 	Enter No of records- 2
# 	Enter Details of student-1
# 	Enter Student name- Manohar
# 	Enter Higher Education- B.Tech
# 	Enter Primary Skill- Python
# 	Enter Year of Graduation- 2022
# 	Enter Details of student-2
# 	Enter Student name- Ponian
# 	Enter Higher Education- B.Sc.
# 	Enter Primary Skill- C++
# 	Enter Year of Graduation- 2020

# 	Enter Job Role Requirement
# 	Enter Skill- Python
# 	Enter Higher Education- B.Tech
# 	Enter Year of Graduation- 2022
# 	Output

# 	('Manohar', 'B.tech', 'Python', '2022')


# Input student records
n = 2 # Replaced input() with example value
# students = [tuple(input(f"Enter Student {i+1} details (name, education, skill, year) separated by commas: ").split(','))
#             for i in range(n)]

# Hardcoded student data based on the example
students = [
    ('Manohar', 'B.Tech', 'Python', '2022'),
    ('Ponian', 'B.Sc.', 'C++', '2020')
]

# req_skill = input("Enter Skill- ")
# req_education = input("Enter Higher Education- ")
# req_year = input("Enter Year of Graduation- ")

# Hardcoded job role requirements based on the example
req_skill = "Python"
req_education = "B.Tech"
req_year = "2022"

found = False
for s in students:
    # Using .strip() for robustness against potential leading/trailing spaces from split or user input
    if s[2].strip() == req_skill.strip() and s[1].strip() == req_education.strip() and s[3].strip() == req_year.strip():
        print(s)
        found = True

if not found:
    print("No such candidate")
# Out:
# ('Manohar', 'B.Tech', 'Python', '2022')

# %%
n = int(input("Enter No of records- "))

students = []

for i in range(n):
    print("Enter Details of student-", i+1)
    name = input("Enter Student name- ")
    edu = input("Enter Higher Education- ")
    skill = input("Enter Primary Skill- ")
    year = input("Enter Year of Graduation- ")

    students.append((name, edu, skill, year))

print("Enter Job Role Requirement")
r_skill = input("Enter Skill- ")
r_edu = input("Enter Higher Education- ")
r_year = input("Enter Year of Graduation- ")

found = 0

for s in students:
    if s[1] == r_edu and s[2] == r_skill and s[3] == r_year:
        print(s)
        found = 1

if found == 0:
    print("No such candidate")
# Out:
# Enter your name

# %%
# 10. Write a program to find set of common elements in three lists using sets.

# 	Input : ar1 = [1, 5, 10, 20, 40, 80]
# 			ar2 = [6, 7, 20, 80, 100]
# 			ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
# Output : [80, 20}


ar1 = [1, 5, 10, 20, 40, 80]
ar2 = [6, 7, 20, 80, 100]
ar3 = [3, 4, 15, 20, 30, 70, 80, 120]
common_elements = list(set(ar1) & set(ar2) & set(ar3))
print(common_elements)
# Out:
# [80, 20]

# %%
# 11. Write a program to count unique number of vowels using sets in a given string. Lowercase and upercase vowels will be taken as different.

# 	Input:

# 	Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
# 	Output:

# 	No of unique vowels-6

Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"
unique_vowels = set(Str1) & set("aeiouAEIOU")
print("No of unique vowels-", len(unique_vowels))
# Out:
# No of unique vowels- 6

# %%
# 13. Convert a list of Tuples into Dictionary.
# 	Example 1:

# 	Input:
# 	[("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
# 	Output:
# 	{'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# 	Example 2:
# Input
data = [("akash", 10), ("gaurav", 12), ("anand", 14), ("suraj", 20), ("akhil", 25), ("ashish", 30)]
result = {}
for key, value in data:
    result[key] = [value]

print(result)

# 	Input:
# 	[('A', 1), ('B', 2), ('C', 3)]
# 	Output:
# 	{'A': [1], 'B': [2], 'C': [3]}
data = [('A', 1), ('B', 2), ('C', 3)]
result = {k: [v] for k, v in data}
print(result)
# Out:
# {'akash': [10], 'gaurav': [12], 'anand': [14], 'suraj': [20], 'akhil': [25], 'ashish': [30]}
# {'A': [1], 'B': [2], 'C': [3]}

# %%
# 14. Write a Python function that takes a list and returns a new list with unique elements of the first list.
# 	Exercise 1:

# 	Input:

# 	[1,2,3,3,3,3,4,5]
# 	Output:

# 	[1, 2, 3, 4, 5]

def unique_list(lst):
    return list(set(lst))
data = [1,2,3,3,3,3,4,5]

print(unique_list(data))
# Out:
# [1, 2, 3, 4, 5]

# %%
# 15.  Write a Python program to print the even numbers from a given list.
		# Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
		# Expected Result : [2, 4, 6, 8]
data = [1, 2, 3, 4, 5, 6, 7, 8, 9]
even_numbers = [num for num in data if num % 2 == 0]
print(even_numbers)
# Out:
# [2, 4, 6, 8]

# %%
# 16. Write a Python function to check whether a number is perfect or not.¶
# 	A Perfect number is a number that is half the sum of all of its positive divisors (including itself).

# 	Example :
# 	The first perfect number is 6, because 1, 2, and 3 are its proper positive divisors, and 1 + 2 + 3 = 6.
# 	Equivalently, the number 6 is equal to half the sum of all its positive divisors: ( 1 + 2 + 3 + 6 ) / 2 = 6.
# 	The next perfect number is 28 = 1 + 2 + 4 + 7 + 14. This is followed by the perfect numbers 496 and 8128.

def sum_divisors(n, i=1):
    if i == n:
        return 0
    if n % i == 0:
        return i + sum_divisors(n, i + 1)
    return sum_divisors(n, i + 1)

def is_perfect(n):
    return n > 1 and sum_divisors(n) == n

print(is_perfect(496))
# Out:
# True

# %%
# 17. Write a Python function to concatenate any no of dictionaries to create a new one.
# 	Sample Dictionary :
# 	dic1={1:10, 2:20}
# 	dic2={3:30, 4:40}
# 	dic3={5:50,6:60}
# 	Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
def merge_dicts(*dicts):
    result = {}
    for d in dicts:
        for i in d:
            result[i] = d[i]
    return result

# Sample Dictionary :
dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}

print(merge_dicts(dic1, dic2, dic3))
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# 18. Write a python function that receives a list of integers and prints out a histogram of bin size 10

# 	Input:
# 	[13,42,15,37,22,39,41,50]
# 	Output:
# 	{11-20:2,21-30:1,31-40:2,41-50:3}
